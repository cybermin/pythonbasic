# %% [markdown]
# # 판다스(pandas)
# + 파이썬에서 사용하는 데이터분석 라이브러리
#
# + 행과 열로 이루어진 데이터 객체를 만들어 다룰 수 있게 되며 보다 안정적으로 대용량의 데이터들을 처리하는데 매우 편리한 도구
#
# + NumPy를 기반으로 구축되었으며 과학 컴퓨팅 환경 내에서 다른 많은 타사 라이브러리와 잘 통합되도록 설계

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ##DataFrame
# + 2차원 자료구조인 DataFrame는 행과 열이 있는 테이블 데이터
# + 딕션너리를 데이터 프레임으로 변경
#  - 딕션너리 키 : 열(column)
#  - 딕션너리 값 : 행(row)

# %%
df = pd.read_csv('/content/drive/My Drive/PythonWork/PythonBasic/04/부산쓰레기발생2017년.csv', engine='python', encoding='CP949')
df
# Out:
#         항목    구분     중구     서구     동구   ...   강서구    연제구    수영구    사상구    기장군
# 0    매립처리량  연간(톤)   3034   2323   1653  ...   9742   1831   2205   9937   2290
# 1    매립처리량  일일(톤)      8      7      5  ...     27      5      6     27      6
# 2    소각처리량  연간(톤)  13729  10446   8297  ...   4788  14521  11987    216  13687
# 3    소각처리량  일일(톤)     38     29     23  ...     13     40     33      0     37
# 4   재활용처리량  연간(톤)   9082  21301  17968  ...  25977  37115  28135  57110  15170
# 5   재활용처리량  일일(톤)     25     58     49  ...     71    102     77    156     42
# 6  음식물류발생량  연간(톤)   5154   8779   6399  ...  10810  14122  13289  24161  16648
# 7  음식물류발생량  일일(톤)     14     24     18  ...     30     39     36     66     46
#
# [8 rows x 18 columns]

# %%
df.columns = [item.strip() for item in df.columns]
df.columns
# Out:
# Index(['항목', '구분', '중구', '서구', '동구', '영도구', '부산진구', '동래구', '남구', '북구', '해운대구',
#        '사하구', '금정구', '강서구', '연제구', '수영구', '사상구', '기장군'],
#       dtype='object')

# %% [markdown]
# ####**N행 확인하기**
# + .head(N)
#   - 데이터프레임의 상위 N개의 행을 출력
#   - N생략하면 5개
# + .tail(N)
#  - 하위 N개의 행을 출력

# %%
df.head()
# Out:
#        항목     구분     중구     서구     동구  ...    강서구    연제구    수영구    사상구    기장군
# 0   매립처리량  연간(톤)   3034   2323   1653  ...   9742   1831   2205   9937   2290
# 1   매립처리량  일일(톤)      8      7      5  ...     27      5      6     27      6
# 2   소각처리량  연간(톤)  13729  10446   8297  ...   4788  14521  11987    216  13687
# 3   소각처리량  일일(톤)     38     29     23  ...     13     40     33      0     37
# 4  재활용처리량  연간(톤)   9082  21301  17968  ...  25977  37115  28135  57110  15170
#
# [5 rows x 18 columns]

# %%
df.head(2)
# Out:
#       항목     구분    중구    서구    동구   영도구  ...   금정구   강서구   연제구   수영구   사상구   기장군
# 0  매립처리량  연간(톤)  3034  2323  1653  1219  ...  7240  9742  1831  2205  9937  2290
# 1  매립처리량  일일(톤)     8     7     5     3  ...    20    27     5     6    27     6
#
# [2 rows x 18 columns]

# %%
df.tail(2)
# Out:
#         항목     구분    중구    서구    동구  ...    강서구    연제구    수영구    사상구    기장군
# 6  음식물류발생량  연간(톤)  5154  8779  6399  ...  10810  14122  13289  24161  16648
# 7  음식물류발생량  일일(톤)    14    24    18  ...     30     39     36     66     46
#
# [2 rows x 18 columns]

# %% [markdown]
# ####**정보 확인하기**
# + .shape 속성
#  - (행, 열) 크기를 확인하기
#  - 행의 개수 : len(데이터프레임), len(.index), .shape[0]
#  - 열의 개수 : len(.column), .shape[1]

# %%
df.shape
# Out:
# (8, 18)

# %%
#행의 개수
print(df.shape[0])
print(len(df))
print(len(df.index))
# Out:
# 8
# 8
# 8

# %%
#열의 개수
print(df.shape[1]) 
print(len(df.columns))
# Out:
# 18
# 18

# %% [markdown]
# + .info()
#  - 데이터프레임에 대한 전반적인 정보
#  - 데이터프레임을 구성하는 행과 열의 크기, 컬럼명, 컬럼을 구성하는 값의 자료형 등을 출력

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   항목      8 non-null      object
#  1   구분      8 non-null      object
#  2   중구      8 non-null      int64
#  3   서구      8 non-null      int64
#  4   동구      8 non-null      int64
#  5   영도구     8 non-null      int64
#  6   부산진구    8 non-null      int64
#  7   동래구     8 non-null      int64
#  8   남구      8 non-null      int64
#  9   북구      8 non-null      int64
#  10  해운대구    8 non-null      int64
#  11  사하구     8 non-null      int64
#  12  금정구     8 non-null      int64
#  13  강서구     8 non-null      int64
#  14  연제구     8 non-null      int64
#  15  수영구     8 non-null      int64
#  16  사상구     8 non-null      int64
#  17  기장군     8 non-null      int64
# dtypes: int64(16), object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# + .count()
#  - Null이 아닌 행의 개수 확인
#  - axis='columns' : Null이 아닌 열의 개수 확인

# %%
df.count()
# Out:
# 항목      8
# 구분      8
# 중구      8
# 서구      8
# 동구      8
# 영도구     8
# 부산진구    8
# 동래구     8
# 남구      8
# 북구      8
# 해운대구    8
# 사하구     8
# 금정구     8
# 강서구     8
# 연제구     8
# 수영구     8
# 사상구     8
# 기장군     8
# dtype: int64

# %%
df.count(axis='columns')
# Out:
# 0    18
# 1    18
# 2    18
# 3    18
# 4    18
# 5    18
# 6    18
# 7    18
# dtype: int64

# %% [markdown]
# ####**값이 나온 횟수**
# + .value_counts()
#  - 개별 컬럼 내에 각각의 값이 나온 횟수
#  - normalize 옵션 : % 로도 표현

# %%
df['구분'].value_counts()
# Out:
# 연간(톤)    4
# 일일(톤)    4
# Name: 구분, dtype: int64

# %%
df['구분'].value_counts(normalize = True)
# Out:
# 연간(톤)    0.5
# 일일(톤)    0.5
# Name: 구분, dtype: float64

# %% [markdown]
# ####**요약 통계량 확인**
# + .describe()
#  - 데이터프레임의 열별 요약 통계량
#  - sum(),mean(), max(), median()등 개별 함수를 사용가능

# %%
df.sum()
# Out:
# 항목      매립처리량매립처리량소각처리량소각처리량재활용처리량재활용처리량음식물류발생량음식물류발생량
# 구분            연간(톤)일일(톤)연간(톤)일일(톤)연간(톤)일일(톤)연간(톤)일일(톤)
# 중구                                               31084
# 서구                                               42967
# 동구                                               34412
# 영도구                                              44129
# 부산진구                                            133869
# 동래구                                              86101
# 남구                                               81893
# 북구                                               98945
# 해운대구                                            142273
# 사하구                                             128215
# 금정구                                              85121
# 강서구                                              51458
# 연제구                                              67775
# 수영구                                              55768
# 사상구                                              91673
# 기장군                                              47926
# dtype: object

# %%
df.mean()
# Out:
# 중구       3885.500
# 서구       5370.875
# 동구       4301.500
# 영도구      5516.125
# 부산진구    16733.625
# 동래구     10762.625
# 남구      10236.625
# 북구      12368.125
# 해운대구    17784.125
# 사하구     16026.875
# 금정구     10640.125
# 강서구      6432.250
# 연제구      8471.875
# 수영구      6971.000
# 사상구     11459.125
# 기장군      5990.750
# dtype: float64

# %%
df.mean(axis=1)
# Out:
# 0     5933.8750
# 1       16.2500
# 2     9496.8125
# 3       26.0000
# 4    43437.2500
# 5      119.0000
# 6    17398.6875
# 7       47.6875
# dtype: float64

# %%
dfyear = df[df['구분'] == '연간(톤)']
dfyear
# Out:
#         항목     구분     중구     서구     동구  ...    강서구    연제구    수영구    사상구    기장군
# 0    매립처리량  연간(톤)   3034   2323   1653  ...   9742   1831   2205   9937   2290
# 2    소각처리량  연간(톤)  13729  10446   8297  ...   4788  14521  11987    216  13687
# 4   재활용처리량  연간(톤)   9082  21301  17968  ...  25977  37115  28135  57110  15170
# 6  음식물류발생량  연간(톤)   5154   8779   6399  ...  10810  14122  13289  24161  16648
#
# [4 rows x 18 columns]

# %%
dfyear.describe()
# Out:
#                  중구            서구  ...           사상구           기장군
# count      4.000000      4.000000  ...      4.000000      4.000000
# mean    7749.750000  10712.250000  ...  22856.000000  11948.750000
# std     4708.238763   7880.555961  ...  24863.022758   6551.650346
# min     3034.000000   2323.000000  ...    216.000000   2290.000000
# 25%     4624.000000   7165.000000  ...   7506.750000  10837.750000
# 50%     7118.000000   9612.500000  ...  17049.000000  14428.500000
# 75%    10243.750000  13159.750000  ...  32398.250000  15539.500000
# max    13729.000000  21301.000000  ...  57110.000000  16648.000000
#
# [8 rows x 16 columns]

# %% [markdown]
# ####**시리즈 내에 유일한 값 확인**
# + .unique()
#  - 개별 컬럼 내에 유일한 값을 확인

# %%
df['구분'].unique()
# Out:
# array(['연간(톤)', '일일(톤)'], dtype=object)

# %%
df['금정구'].unique()
# Out:
# array([ 7240,    20,   222,     1, 56153,   154, 21273,    58])

# %% [markdown]
# ## **데이터프레임 슬라이싱**
# + .loc[행인덱싱, 열인덱싱]
# + .iloc[행순서번호, 열순서번호]

# %%
df2 = df.set_index('항목')
df2
# Out:
#             구분     중구     서구     동구    영도구  ...    강서구    연제구    수영구    사상구    기장군
# 항목                                          ...
# 매립처리량    연간(톤)   3034   2323   1653   1219  ...   9742   1831   2205   9937   2290
# 매립처리량    일일(톤)      8      7      5      3  ...     27      5      6     27      6
# 소각처리량    연간(톤)  13729  10446   8297   8651  ...   4788  14521  11987    216  13687
# 소각처리량    일일(톤)     38     29     23     24  ...     13     40     33      0     37
# 재활용처리량   연간(톤)   9082  21301  17968  24616  ...  25977  37115  28135  57110  15170
# 재활용처리량   일일(톤)     25     58     49     68  ...     71    102     77    156     42
# 음식물류발생량  연간(톤)   5154   8779   6399   9522  ...  10810  14122  13289  24161  16648
# 음식물류발생량  일일(톤)     14     24     18     26  ...     30     39     36     66     46
#
# [8 rows x 17 columns]

# %% [markdown]
# #### **.loc : 인덱싱으로 추출**

# %%
#행추출
df2.loc['매립처리량']
# Out:
#           구분    중구    서구    동구   영도구   부산진구  ...   금정구   강서구   연제구   수영구   사상구   기장군
# 항목                                           ...
# 매립처리량  연간(톤)  3034  2323  1653  1219  17393  ...  7240  9742  1831  2205  9937  2290
# 매립처리량  일일(톤)     8     7     5     3     48  ...    20    27     5     6    27     6
#
# [2 rows x 17 columns]

# %%
df2.loc[['매립처리량','재활용처리량']]
# Out:
#            구분    중구     서구     동구    영도구  ...    강서구    연제구    수영구    사상구    기장군
# 항목                                        ...
# 매립처리량   연간(톤)  3034   2323   1653   1219  ...   9742   1831   2205   9937   2290
# 매립처리량   일일(톤)     8      7      5      3  ...     27      5      6     27      6
# 재활용처리량  연간(톤)  9082  21301  17968  24616  ...  25977  37115  28135  57110  15170
# 재활용처리량  일일(톤)    25     58     49     68  ...     71    102     77    156     42
#
# [4 rows x 17 columns]

# %%
#열추출
df2.loc[:, '금정구']
# Out:
# 항목
# 매립처리량       7240
# 매립처리량         20
# 소각처리량        222
# 소각처리량          1
# 재활용처리량     56153
# 재활용처리량       154
# 음식물류발생량    21273
# 음식물류발생량       58
# Name: 금정구, dtype: int64

# %%
df2.loc[:, ['구분','금정구']]
# Out:
#             구분    금정구
# 항목
# 매립처리량    연간(톤)   7240
# 매립처리량    일일(톤)     20
# 소각처리량    연간(톤)    222
# 소각처리량    일일(톤)      1
# 재활용처리량   연간(톤)  56153
# 재활용처리량   일일(톤)    154
# 음식물류발생량  연간(톤)  21273
# 음식물류발생량  일일(톤)     58

# %%
df2.loc[['매립처리량','재활용처리량'], ['구분','금정구']]
# Out:
#            구분    금정구
# 항목
# 매립처리량   연간(톤)   7240
# 매립처리량   일일(톤)     20
# 재활용처리량  연간(톤)  56153
# 재활용처리량  일일(톤)    154

# %% [markdown]
# #### **.iloc : 순서번호로 추출**

# %%
#행추출
df2.iloc[:2]
# Out:
#           구분    중구    서구    동구   영도구   부산진구  ...   금정구   강서구   연제구   수영구   사상구   기장군
# 항목                                           ...
# 매립처리량  연간(톤)  3034  2323  1653  1219  17393  ...  7240  9742  1831  2205  9937  2290
# 매립처리량  일일(톤)     8     7     5     3     48  ...    20    27     5     6    27     6
#
# [2 rows x 17 columns]

# %%
df2.iloc[[0,1,4,5]]
# Out:
#            구분    중구     서구     동구    영도구  ...    강서구    연제구    수영구    사상구    기장군
# 항목                                        ...
# 매립처리량   연간(톤)  3034   2323   1653   1219  ...   9742   1831   2205   9937   2290
# 매립처리량   일일(톤)     8      7      5      3  ...     27      5      6     27      6
# 재활용처리량  연간(톤)  9082  21301  17968  24616  ...  25977  37115  28135  57110  15170
# 재활용처리량  일일(톤)    25     58     49     68  ...     71    102     77    156     42
#
# [4 rows x 17 columns]

# %%
df2.iloc[[0:2]]
# Out:
#   File "<ipython-input-114-4436bd4d9b69>", line 1
#     df2.iloc[[0:2]]
#                ^
# SyntaxError: invalid syntax

# %%
df2.iloc[[0,2]]
# Out:
#           구분     중구     서구    동구   영도구  ...   강서구    연제구    수영구   사상구    기장군
# 항목                                      ...
# 매립처리량  연간(톤)   3034   2323  1653  1219  ...  9742   1831   2205  9937   2290
# 소각처리량  연간(톤)  13729  10446  8297  8651  ...  4788  14521  11987   216  13687
#
# [2 rows x 17 columns]

# %%
#열추출
df2.iloc[:, 11]
# Out:
# 항목
# 매립처리량       7240
# 매립처리량         20
# 소각처리량        222
# 소각처리량          1
# 재활용처리량     56153
# 재활용처리량       154
# 음식물류발생량    21273
# 음식물류발생량       58
# Name: 금정구, dtype: int64

# %%
df2.iloc[:, [0,11]]
# Out:
#             구분    금정구
# 항목
# 매립처리량    연간(톤)   7240
# 매립처리량    일일(톤)     20
# 소각처리량    연간(톤)    222
# 소각처리량    일일(톤)      1
# 재활용처리량   연간(톤)  56153
# 재활용처리량   일일(톤)    154
# 음식물류발생량  연간(톤)  21273
# 음식물류발생량  일일(톤)     58

# %%
df21 = df2.iloc[[0,1,4,5], [0,11]]
df21
# Out:
#            구분    금정구
# 항목
# 매립처리량   연간(톤)   7240
# 매립처리량   일일(톤)     20
# 재활용처리량  연간(톤)  56153
# 재활용처리량  일일(톤)    154

# %% [markdown]
# #### 해결문제

# %% [markdown]
# ---
# 해결문제) 부산시기온.csv파일을 읽어서 2018년 최고, 최저 기온을 추출하고 통계량을 표시하시오.
#
#
# ---

# %%
dfbusan = pd.read_csv('/content/drive/My Drive/PythonWork/PythonBasic/04/부산시기온.csv',engine='python')
dfbusan
# Out:
#             일시    평균    최고    최저
# 0   2017-01-01   4.1  15.1  -7.7
# 1   2017-02-01   5.5  17.7  -5.7
# 2   2017-03-01   9.0  18.1  -2.3
# 3   2017-04-01  15.0  23.2   5.0
# 4   2017-05-01  19.0  28.2  12.8
# 5   2017-06-01  21.3  30.4  15.4
# 6   2017-07-01  26.1  32.7  21.2
# 7   2017-08-01  27.0  36.2  18.7
# 8   2017-09-01  22.6  29.7  14.5
# 9   2017-10-01  18.1  28.7   7.3
# 10  2017-11-01  11.2  23.6  -1.0
# 11  2017-12-01   3.6  14.5  -6.1
# 12  2018-01-01   1.9  14.0  -9.9
# 13  2018-02-01   3.9  14.7  -9.6
# 14  2018-03-01  10.0  22.3  -0.7
# 15  2018-04-01  14.5  24.3   3.0
# 16  2018-05-01  17.8  26.6   9.8
# 17  2018-06-01  21.5  31.3  15.1
# 18  2018-07-01  26.7  35.4  17.8
# 19  2018-08-01  27.9  36.4  21.2
# 20  2018-09-01  21.9  30.0  14.9
# 21  2018-10-01  16.4  25.6   7.9
# 22  2018-11-01  12.4  22.5   2.7
# 23  2018-12-01   5.7  18.8  -7.1
# 24  2019-01-01   4.5  13.7  -4.4
# 25  2019-02-01   6.6  16.5  -4.2
# 26  2019-03-01  10.5  21.0   0.5
# 27  2019-04-01  13.4  23.4   2.1
# 28  2019-05-01  19.3  30.1  11.0
# 29  2019-06-01  21.1  29.7  15.5

# %%
dfbusan.columns
# Out:
# Index(['일시', '평균', '최고', '최저'], dtype='object')

# %%
dfbusan = dfbusan.loc[12:23, ['일시','최고','최저']]
dfbusan
# Out:
#             일시    최고    최저
# 12  2018-01-01  14.0  -9.9
# 13  2018-02-01  14.7  -9.6
# 14  2018-03-01  22.3  -0.7
# 15  2018-04-01  24.3   3.0
# 16  2018-05-01  26.6   9.8
# 17  2018-06-01  31.3  15.1
# 18  2018-07-01  35.4  17.8
# 19  2018-08-01  36.4  21.2
# 20  2018-09-01  30.0  14.9
# 21  2018-10-01  25.6   7.9
# 22  2018-11-01  22.5   2.7
# 23  2018-12-01  18.8  -7.1

# %%
dfbusan.describe()
# Out:
#               최고         최저
# count  12.000000  12.000000
# mean   25.158333   5.425000
# std     7.292519  10.782741
# min    14.000000  -9.900000
# 25%    21.425000  -2.300000
# 50%    24.950000   5.450000
# 75%    30.325000  14.950000
# max    36.400000  21.200000

# %% [markdown]
# #### 데이터 유형 확인
# + 데이터프레임.dtypes : 각열의 유형을 알려줌

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 18 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   항목      8 non-null      object
#  1   구분      8 non-null      object
#  2   중구      8 non-null      int64
#  3   서구      8 non-null      int64
#  4   동구      8 non-null      int64
#  5   영도구     8 non-null      int64
#  6   부산진구    8 non-null      int64
#  7   동래구     8 non-null      int64
#  8   남구      8 non-null      int64
#  9   북구      8 non-null      int64
#  10  해운대구    8 non-null      int64
#  11  사하구     8 non-null      int64
#  12  금정구     8 non-null      int64
#  13  강서구     8 non-null      int64
#  14  연제구     8 non-null      int64
#  15  수영구     8 non-null      int64
#  16  사상구     8 non-null      int64
#  17  기장군     8 non-null      int64
# dtypes: int64(16), object(2)
# memory usage: 1.2+ KB

# %% [markdown]
# ##### 열시리즈.astype() : 특정 유형으로 변경
#  - .astype(float64) , .astype(float32) , .astype(float16), .astype(int)
#  - .astype(str)

# %%
df = dfbusan

# %%
df['차이'] = df['최고'] - df['최저']
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 12 to 23
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      12 non-null     object
#  1   최고      12 non-null     float64
#  2   최저      12 non-null     float64
#  3   차이      12 non-null     float64
# dtypes: float64(3), object(1)
# memory usage: 516.0+ bytes

# %%
df['차이'] = df['차이'].astype(int)
df.dtypes
# Out:
# 일시     object
# 최고    float64
# 최저    float64
# 차이      int64
# dtype: object

# %%
df.head(2)
# Out:
#             일시    최고   최저  차이
# 12  2018-01-01  14.0 -9.9  23
# 13  2018-02-01  14.7 -9.6  24

# %% [markdown]
# ##### pd.to_numeric() : 숫자 유형으로 변경
#  - errors 매개 변수
#  - errors='ignore' : 무시
#  - errors='coerce' : NaN

# %%
lt = ['1','2','a']
df2 = pd.DataFrame(lt)
df2.columns = ['자료']
df2
# Out:
#   자료
# 0  1
# 1  2
# 2  a

# %%
df2.dtypes
# Out:
# 자료    object
# dtype: object

# %%
df2['자료'] = pd.to_numeric(df2['자료'])
df2.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "a"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-133-74e89c34f6e8> in <module>()
# ----> 1 df2['자료'] = pd.to_numeric(df2['자료'])
#       2 df2.dtypes
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     148         try:
#     149             values = lib.maybe_convert_numeric(
# --> 150                 values, set(), coerce_numeric=coerce_numeric
#     151             )
#     152         except (ValueError, TypeError):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "a" at position 2

# %%
df2['자료'] = pd.to_numeric(df2['자료'], errors='ignore')
df2
# Out:
#   자료
# 0  1
# 1  2
# 2  a

# %%
df2.dtypes
# Out:
# 자료    object
# dtype: object

# %%
df2['자료'] = pd.to_numeric(df2['자료'], errors='coerce' )
df2
# Out:
#     자료
# 0  1.0
# 1  2.0
# 2  NaN

# %%
df2.dtypes
# Out:
# 자료    float64
# dtype: object

# %% [markdown]
# ##### pd.to_datetime(열명)
#  - .dt.year : 년도
#  - .dt.month : 월
#  - .dt.day : 일

# %% [markdown]
# 참고 ) Accessors(접근자) : dtype 관련 메소드로 Series 내에서 특정 데이터 형식에만 적용되는 별도의 네임 스페이스
#
# [참고사이트](https://pandas.pydata.org/pandas-docs/stable/reference/series.html#time-series-related)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 12 to 23
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      12 non-null     object
#  1   최고      12 non-null     float64
#  2   최저      12 non-null     float64
#  3   차이      12 non-null     int64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 516.0+ bytes

# %%
df['일시'] = pd.to_datetime(df['일시'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 12 to 23
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      12 non-null     datetime64[ns]
#  1   최고      12 non-null     float64
#  2   최저      12 non-null     float64
#  3   차이      12 non-null     int64
# dtypes: datetime64[ns](1), float64(2), int64(1)
# memory usage: 516.0 bytes

# %%
df['일시'].dt.year
# Out:
# 12    2018
# 13    2018
# 14    2018
# 15    2018
# 16    2018
# 17    2018
# 18    2018
# 19    2018
# 20    2018
# 21    2018
# 22    2018
# 23    2018
# Name: 일시, dtype: int64

# %% [markdown]
# #### 행과 열 추가

# %% [markdown]
# #####**열 추가**

# %%
dfbusan['일시'] = pd.to_datetime(dfbusan['일시'])

# %%
dfbusan['년도'] = dfbusan['일시'].dt.year
dfbusan['월'] = dfbusan['일시'].dt.month
dfbusan['일'] = dfbusan['일시'].dt.day
dfbusan
# Out:
#            일시    최고    최저    년도   월  일
# 12 2018-01-01  14.0  -9.9  2018   1  1
# 13 2018-02-01  14.7  -9.6  2018   2  1
# 14 2018-03-01  22.3  -0.7  2018   3  1
# 15 2018-04-01  24.3   3.0  2018   4  1
# 16 2018-05-01  26.6   9.8  2018   5  1
# 17 2018-06-01  31.3  15.1  2018   6  1
# 18 2018-07-01  35.4  17.8  2018   7  1
# 19 2018-08-01  36.4  21.2  2018   8  1
# 20 2018-09-01  30.0  14.9  2018   9  1
# 21 2018-10-01  25.6   7.9  2018  10  1
# 22 2018-11-01  22.5   2.7  2018  11  1
# 23 2018-12-01  18.8  -7.1  2018  12  1

# %%
dfbusan[['최고','최저']].mean(axis=1)
# Out:
# 12     2.05
# 13     2.55
# 14    10.80
# 15    13.65
# 16    18.20
# 17    23.20
# 18    26.60
# 19    28.80
# 20    22.45
# 21    16.75
# 22    12.60
# 23     5.85
# dtype: float64

# %%
dfbusan['평균'] = dfbusan[['최고','최저']].mean(axis=1)
dfbusan
# Out:
#            일시    최고    최저    년도   월  일     평균
# 12 2018-01-01  14.0  -9.9  2018   1  1   2.05
# 13 2018-02-01  14.7  -9.6  2018   2  1   2.55
# 14 2018-03-01  22.3  -0.7  2018   3  1  10.80
# 15 2018-04-01  24.3   3.0  2018   4  1  13.65
# 16 2018-05-01  26.6   9.8  2018   5  1  18.20
# 17 2018-06-01  31.3  15.1  2018   6  1  23.20
# 18 2018-07-01  35.4  17.8  2018   7  1  26.60
# 19 2018-08-01  36.4  21.2  2018   8  1  28.80
# 20 2018-09-01  30.0  14.9  2018   9  1  22.45
# 21 2018-10-01  25.6   7.9  2018  10  1  16.75
# 22 2018-11-01  22.5   2.7  2018  11  1  12.60
# 23 2018-12-01  18.8  -7.1  2018  12  1   5.85

# %%
dfbusan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 12 to 23
# Data columns (total 7 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      12 non-null     datetime64[ns]
#  1   최고      12 non-null     float64
#  2   최저      12 non-null     float64
#  3   년도      12 non-null     int64
#  4   월       12 non-null     int64
#  5   일       12 non-null     int64
#  6   평균      12 non-null     float64
# dtypes: datetime64[ns](1), float64(3), int64(3)
# memory usage: 804.0 bytes

# %%
dfbusan = dfbusan.drop('분기', axis=1)

# %%
dfbusan.loc[(dfbusan['일시'].dt.month >= 1) & (dfbusan['일시'].dt.month <= 3), '분기'] = 1
dfbusan.loc[(dfbusan['일시'].dt.month >= 4) & (dfbusan['일시'].dt.month <= 6), '분기'] = 2
dfbusan.loc[(dfbusan['일시'].dt.month >= 7) & (dfbusan['일시'].dt.month <= 9), '분기'] = 3
dfbusan.loc[(dfbusan['일시'].dt.month >= 10) & (dfbusan['일시'].dt.month <= 12), '분기'] = 4

# %%
dfbusan.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 12 to 23
# Data columns (total 8 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   일시      12 non-null     datetime64[ns]
#  1   최고      12 non-null     float64
#  2   최저      12 non-null     float64
#  3   년도      12 non-null     int64
#  4   월       12 non-null     int64
#  5   일       12 non-null     int64
#  6   평균      12 non-null     float64
#  7   분기      12 non-null     int64
# dtypes: datetime64[ns](1), float64(3), int64(4)
# memory usage: 900.0 bytes

# %%
dfbusan['분기'] = dfbusan['분기'].astype(int)

# %%
dfbusan.head(2)
# Out:
#            일시    최고   최저    년도  월  일    평균  분기
# 12 2018-01-01  14.0 -9.9  2018  1  1  2.05   1
# 13 2018-02-01  14.7 -9.6  2018  2  1  2.55   1

# %%
dfbusan
# Out:
#            일시    최고    최저    년도   월  일     평균   분기
# 12 2018-01-01  14.0  -9.9  2018   1  1   2.05  1.0
# 13 2018-02-01  14.7  -9.6  2018   2  1   2.55  1.0
# 14 2018-03-01  22.3  -0.7  2018   3  1  10.80  1.0
# 15 2018-04-01  24.3   3.0  2018   4  1  13.65  2.0
# 16 2018-05-01  26.6   9.8  2018   5  1  18.20  2.0
# 17 2018-06-01  31.3  15.1  2018   6  1  23.20  2.0
# 18 2018-07-01  35.4  17.8  2018   7  1  26.60  3.0
# 19 2018-08-01  36.4  21.2  2018   8  1  28.80  3.0
# 20 2018-09-01  30.0  14.9  2018   9  1  22.45  3.0
# 21 2018-10-01  25.6   7.9  2018  10  1  16.75  4.0
# 22 2018-11-01  22.5   2.7  2018  11  1  12.60  4.0
# 23 2018-12-01  18.8  -7.1  2018  12  1   5.85  4.0

# %%
dfbusan.loc[(dfbusan['일시'].dt.month >= 1)  &  (dfbusan['일시'].dt.month <= 3 ), '분기'] = 1
dfbusan.loc[(dfbusan['일시'].dt.month >= 4)  &  (dfbusan['일시'].dt.month <= 6 ), '분기'] = 2
dfbusan.loc[(dfbusan['일시'].dt.month >= 7)  &  (dfbusan['일시'].dt.month <= 9 ), '분기'] = 3
dfbusan.loc[(dfbusan['일시'].dt.month >= 10)  &  (dfbusan['일시'].dt.month <= 12 ), '분기'] = 4

# %% [markdown]
# #####**행 추가**

# %%
df.dtypes
# Out:
# 일시    datetime64[ns]
# 최고           float64
# 최저           float64
# 차이             int64
# 년도             int64
# 월              int64
# 일              int64
# 평균           float64
# 분기             int64
# dtype: object

# %%
df['일시'] = df['일시'].astype(str)
df.dtypes
# Out:
# 일시     object
# 최고    float64
# 최저    float64
# 차이      int64
# 년도      int64
# 월       int64
# 일       int64
# 평균    float64
# 분기      int64
# dtype: object

# %%
df = df.set_index('일시')
df
# Out:
#               최고    최저  차이    년도   월  일     평균  분기
# 일시
# 2018-01-01  14.0  -9.9  23  2018   1  1   2.05   0
# 2018-02-01  14.7  -9.6  24  2018   2  1   2.55   0
# 2018-03-01  22.3  -0.7  23  2018   3  1  10.80   0
# 2018-04-01  24.3   3.0  21  2018   4  1  13.65   0
# 2018-05-01  26.6   9.8  16  2018   5  1  18.20   0
# 2018-06-01  31.3  15.1  16  2018   6  1  23.20   0
# 2018-07-01  35.4  17.8  17  2018   7  1  26.60   0
# 2018-08-01  36.4  21.2  15  2018   8  1  28.80   0
# 2018-09-01  30.0  14.9  15  2018   9  1  22.45   0
# 2018-10-01  25.6   7.9  17  2018  10  1  16.75   0
# 2018-11-01  22.5   2.7  19  2018  11  1  12.60   0
# 2018-12-01  18.8  -7.1  25  2018  12  1   5.85   0

# %%
df.mean()
# Out:
# 최고      25.158333
# 최저       5.425000
# 차이      19.250000
# 년도    2018.000000
# 월        6.500000
# 일        1.000000
# 평균      15.291667
# 분기       0.000000
# dtype: float64

# %%
df.loc['평균'] = df.mean()
df
# Out:
#                    최고      최저     차이      년도     월    일         평균   분기
# 일시
# 2018-01-01  14.000000  -9.900  23.00  2018.0   1.0  1.0   2.050000  0.0
# 2018-02-01  14.700000  -9.600  24.00  2018.0   2.0  1.0   2.550000  0.0
# 2018-03-01  22.300000  -0.700  23.00  2018.0   3.0  1.0  10.800000  0.0
# 2018-04-01  24.300000   3.000  21.00  2018.0   4.0  1.0  13.650000  0.0
# 2018-05-01  26.600000   9.800  16.00  2018.0   5.0  1.0  18.200000  0.0
# 2018-06-01  31.300000  15.100  16.00  2018.0   6.0  1.0  23.200000  0.0
# 2018-07-01  35.400000  17.800  17.00  2018.0   7.0  1.0  26.600000  0.0
# 2018-08-01  36.400000  21.200  15.00  2018.0   8.0  1.0  28.800000  0.0
# 2018-09-01  30.000000  14.900  15.00  2018.0   9.0  1.0  22.450000  0.0
# 2018-10-01  25.600000   7.900  17.00  2018.0  10.0  1.0  16.750000  0.0
# 2018-11-01  22.500000   2.700  19.00  2018.0  11.0  1.0  12.600000  0.0
# 2018-12-01  18.800000  -7.100  25.00  2018.0  12.0  1.0   5.850000  0.0
# 평균          25.158333   5.425  19.25  2018.0   6.5  1.0  15.291667  0.0

# %%
df.loc['평균', '일시'] = ''
df.tail(2)
# Out:
#                    최고     최저     차이      년도     월    일         평균   분기   일시
# 일시
# 2018-12-01  18.800000 -7.100  25.00  2018.0  12.0  1.0   5.850000  0.0  NaN
# 평균          25.158333  5.425  19.25  2018.0   6.5  1.0  15.291667  0.0

# %%
df.loc['평균', ['차이','년도','월','일']] = ''
df.tail(2)
# Out:
#                    최고     최저  차이    년도   월  일         평균   분기   일시
# 일시
# 2018-12-01  18.800000 -7.100  25  2018  12  1   5.850000  0.0  NaN
# 평균          25.158333  5.425                   15.291667  0.0

# %% [markdown]
# #### 행열 삭제
# + .drop(행인덱스, axis=0)
# + .drop(열인덱스, axis=1)

# %%
df = df.drop(['월','일'], axis=1)
df
# Out:
#                    최고      최저  차이    년도         평균   분기   일시
# 일시
# 2018-01-01  14.000000  -9.900  23  2018   2.050000  0.0  NaN
# 2018-02-01  14.700000  -9.600  24  2018   2.550000  0.0  NaN
# 2018-03-01  22.300000  -0.700  23  2018  10.800000  0.0  NaN
# 2018-04-01  24.300000   3.000  21  2018  13.650000  0.0  NaN
# 2018-05-01  26.600000   9.800  16  2018  18.200000  0.0  NaN
# 2018-06-01  31.300000  15.100  16  2018  23.200000  0.0  NaN
# 2018-07-01  35.400000  17.800  17  2018  26.600000  0.0  NaN
# 2018-08-01  36.400000  21.200  15  2018  28.800000  0.0  NaN
# 2018-09-01  30.000000  14.900  15  2018  22.450000  0.0  NaN
# 2018-10-01  25.600000   7.900  17  2018  16.750000  0.0  NaN
# 2018-11-01  22.500000   2.700  19  2018  12.600000  0.0  NaN
# 2018-12-01  18.800000  -7.100  25  2018   5.850000  0.0  NaN
# 평균          25.158333   5.425            15.291667  0.0

# %%
df.loc['평균', ['차이', '년도']] = ''
df
# Out:
#                    최고      최저  차이    년도         평균   분기   일시
# 일시
# 2018-01-01  14.000000  -9.900  23  2018   2.050000  0.0  NaN
# 2018-02-01  14.700000  -9.600  24  2018   2.550000  0.0  NaN
# 2018-03-01  22.300000  -0.700  23  2018  10.800000  0.0  NaN
# 2018-04-01  24.300000   3.000  21  2018  13.650000  0.0  NaN
# 2018-05-01  26.600000   9.800  16  2018  18.200000  0.0  NaN
# 2018-06-01  31.300000  15.100  16  2018  23.200000  0.0  NaN
# 2018-07-01  35.400000  17.800  17  2018  26.600000  0.0  NaN
# 2018-08-01  36.400000  21.200  15  2018  28.800000  0.0  NaN
# 2018-09-01  30.000000  14.900  15  2018  22.450000  0.0  NaN
# 2018-10-01  25.600000   7.900  17  2018  16.750000  0.0  NaN
# 2018-11-01  22.500000   2.700  19  2018  12.600000  0.0  NaN
# 2018-12-01  18.800000  -7.100  25  2018   5.850000  0.0  NaN
# 평균          25.158333   5.425            15.291667  0.0

# %%
df = df.drop('평균', axis=0)
df
# Out:
#               최고    최저  차이    년도     평균   분기   일시
# 일시
# 2018-01-01  14.0  -9.9  23  2018   2.05  0.0  NaN
# 2018-02-01  14.7  -9.6  24  2018   2.55  0.0  NaN
# 2018-03-01  22.3  -0.7  23  2018  10.80  0.0  NaN
# 2018-04-01  24.3   3.0  21  2018  13.65  0.0  NaN
# 2018-05-01  26.6   9.8  16  2018  18.20  0.0  NaN
# 2018-06-01  31.3  15.1  16  2018  23.20  0.0  NaN
# 2018-07-01  35.4  17.8  17  2018  26.60  0.0  NaN
# 2018-08-01  36.4  21.2  15  2018  28.80  0.0  NaN
# 2018-09-01  30.0  14.9  15  2018  22.45  0.0  NaN
# 2018-10-01  25.6   7.9  17  2018  16.75  0.0  NaN
# 2018-11-01  22.5   2.7  19  2018  12.60  0.0  NaN
# 2018-12-01  18.8  -7.1  25  2018   5.85  0.0  NaN

# %% [markdown]
# #### 행열 전환
# + 데이터프레임.T

# %%
df21 = df

# %%
df21
# Out:
#               최고    최저  차이    년도     평균   분기   일시
# 일시
# 2018-01-01  14.0  -9.9  23  2018   2.05  0.0  NaN
# 2018-02-01  14.7  -9.6  24  2018   2.55  0.0  NaN
# 2018-03-01  22.3  -0.7  23  2018  10.80  0.0  NaN
# 2018-04-01  24.3   3.0  21  2018  13.65  0.0  NaN
# 2018-05-01  26.6   9.8  16  2018  18.20  0.0  NaN
# 2018-06-01  31.3  15.1  16  2018  23.20  0.0  NaN
# 2018-07-01  35.4  17.8  17  2018  26.60  0.0  NaN
# 2018-08-01  36.4  21.2  15  2018  28.80  0.0  NaN
# 2018-09-01  30.0  14.9  15  2018  22.45  0.0  NaN
# 2018-10-01  25.6   7.9  17  2018  16.75  0.0  NaN
# 2018-11-01  22.5   2.7  19  2018  12.60  0.0  NaN
# 2018-12-01  18.8  -7.1  25  2018   5.85  0.0  NaN

# %%
df21 = df21.T

# %%
df21
# Out:
# 일시 2018-01-01 2018-02-01 2018-03-01  ... 2018-10-01 2018-11-01 2018-12-01
# 최고         14       14.7       22.3  ...       25.6       22.5       18.8
# 최저       -9.9       -9.6       -0.7  ...        7.9        2.7       -7.1
# 차이         23         24         23  ...         17         19         25
# 년도       2018       2018       2018  ...       2018       2018       2018
# 평균       2.05       2.55       10.8  ...      16.75       12.6       5.85
# 분기          0          0          0  ...          0          0          0
# 일시        NaN        NaN        NaN  ...        NaN        NaN        NaN
#
# [7 rows x 12 columns]

# %%
df.head(2)
# Out:
#               최고   최저  차이    년도    평균   분기   일시
# 일시
# 2018-01-01  14.0 -9.9  23  2018  2.05  0.0  NaN
# 2018-02-01  14.7 -9.6  24  2018  2.55  0.0  NaN

# %%
df.sort_values(by='최저')
# Out:
#               최고    최저  차이    년도     평균   분기   일시
# 일시
# 2018-01-01  14.0  -9.9  23  2018   2.05  0.0  NaN
# 2018-02-01  14.7  -9.6  24  2018   2.55  0.0  NaN
# 2018-12-01  18.8  -7.1  25  2018   5.85  0.0  NaN
# 2018-03-01  22.3  -0.7  23  2018  10.80  0.0  NaN
# 2018-11-01  22.5   2.7  19  2018  12.60  0.0  NaN
# 2018-04-01  24.3   3.0  21  2018  13.65  0.0  NaN
# 2018-10-01  25.6   7.9  17  2018  16.75  0.0  NaN
# 2018-05-01  26.6   9.8  16  2018  18.20  0.0  NaN
# 2018-09-01  30.0  14.9  15  2018  22.45  0.0  NaN
# 2018-06-01  31.3  15.1  16  2018  23.20  0.0  NaN
# 2018-07-01  35.4  17.8  17  2018  26.60  0.0  NaN
# 2018-08-01  36.4  21.2  15  2018  28.80  0.0  NaN

# %%
df21.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7 entries, 최고 to 일시
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   2018-01-01  6 non-null      object
#  1   2018-02-01  6 non-null      object
#  2   2018-03-01  6 non-null      object
#  3   2018-04-01  6 non-null      object
#  4   2018-05-01  6 non-null      object
#  5   2018-06-01  6 non-null      object
#  6   2018-07-01  6 non-null      object
#  7   2018-08-01  6 non-null      object
#  8   2018-09-01  6 non-null      object
#  9   2018-10-01  6 non-null      object
#  10  2018-11-01  6 non-null      object
#  11  2018-12-01  6 non-null      object
# dtypes: object(12)
# memory usage: 1.0+ KB

# %% [markdown]
# #### 정렬하기
# + .sort_index()
#  - 인덱스(index)를 기준으로 정렬
# + .sort_values()
#  - 컬럼의 값을 기준으로 데이터를 정렬
#  - 옵션 : by=컬럼 , ascending=False

# %%
df = df.sort_values(by = '차이')
df
# Out:
#               최고    최저  차이    년도     평균   분기   일시
# 일시
# 2018-08-01  36.4  21.2  15  2018  28.80  0.0  NaN
# 2018-09-01  30.0  14.9  15  2018  22.45  0.0  NaN
# 2018-05-01  26.6   9.8  16  2018  18.20  0.0  NaN
# 2018-06-01  31.3  15.1  16  2018  23.20  0.0  NaN
# 2018-07-01  35.4  17.8  17  2018  26.60  0.0  NaN
# 2018-10-01  25.6   7.9  17  2018  16.75  0.0  NaN
# 2018-11-01  22.5   2.7  19  2018  12.60  0.0  NaN
# 2018-04-01  24.3   3.0  21  2018  13.65  0.0  NaN
# 2018-01-01  14.0  -9.9  23  2018   2.05  0.0  NaN
# 2018-03-01  22.3  -0.7  23  2018  10.80  0.0  NaN
# 2018-02-01  14.7  -9.6  24  2018   2.55  0.0  NaN
# 2018-12-01  18.8  -7.1  25  2018   5.85  0.0  NaN

# %%
df = df.sort_index()
df
# Out:
#               최고    최저  차이    년도     평균   분기   일시
# 일시
# 2018-01-01  14.0  -9.9  23  2018   2.05  0.0  NaN
# 2018-02-01  14.7  -9.6  24  2018   2.55  0.0  NaN
# 2018-03-01  22.3  -0.7  23  2018  10.80  0.0  NaN
# 2018-04-01  24.3   3.0  21  2018  13.65  0.0  NaN
# 2018-05-01  26.6   9.8  16  2018  18.20  0.0  NaN
# 2018-06-01  31.3  15.1  16  2018  23.20  0.0  NaN
# 2018-07-01  35.4  17.8  17  2018  26.60  0.0  NaN
# 2018-08-01  36.4  21.2  15  2018  28.80  0.0  NaN
# 2018-09-01  30.0  14.9  15  2018  22.45  0.0  NaN
# 2018-10-01  25.6   7.9  17  2018  16.75  0.0  NaN
# 2018-11-01  22.5   2.7  19  2018  12.60  0.0  NaN
# 2018-12-01  18.8  -7.1  25  2018   5.85  0.0  NaN

# %% [markdown]
# #### 특정 인덱스 명 변경
# + 인덱스 변경
#  - 데이터프레임.rename(index = {'Old Name': 'New Name'})
# + 컬럼명 변경
#  - 데이터프레임.rename(columns = {'Old Name': 'New Name'})

# %%
df = dfbusan

# %%
df
# Out:
#             일시    최고    최저  차이    년도   월  일     평균  분기
# 12  2018-01-01  14.0  -9.9  23  2018   1  1   2.05   0
# 13  2018-02-01  14.7  -9.6  24  2018   2  1   2.55   0
# 14  2018-03-01  22.3  -0.7  23  2018   3  1  10.80   0
# 15  2018-04-01  24.3   3.0  21  2018   4  1  13.65   0
# 16  2018-05-01  26.6   9.8  16  2018   5  1  18.20   0
# 17  2018-06-01  31.3  15.1  16  2018   6  1  23.20   0
# 18  2018-07-01  35.4  17.8  17  2018   7  1  26.60   0
# 19  2018-08-01  36.4  21.2  15  2018   8  1  28.80   0
# 20  2018-09-01  30.0  14.9  15  2018   9  1  22.45   0
# 21  2018-10-01  25.6   7.9  17  2018  10  1  16.75   0
# 22  2018-11-01  22.5   2.7  19  2018  11  1  12.60   0
# 23  2018-12-01  18.8  -7.1  25  2018  12  1   5.85   0

# %%
df['평균'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### 해결문제

# %% [markdown]
# ---
# 해결문제) mv1.csv 파일을 읽어서 2019년 자료를 추출하여 평점 평균을 구하시오.
#
#
# ```
# 	        영화명	                 순위	  평점
# 일자
# 2019-07-31	마이펫의 이중생활 2	        47	  7.900000
# 2019-06-19	롱 리브 더 킹: 목포 영웅	48    7.600000
# 2019-12-11	쥬만지: 넥스트 레벨	        49	  5.900000
# 2019-06-26	존 윅 3: 파라벨룸	        50	  6.900000
# 평균			                              7.48163
# ```
#
#
#
# ---

# %%
dfmv = pd.read_csv('/content/drive/My Drive/PythonWork/PythonBasic/04/mv1.csv',names=['영화코드', '순위', '링크', '영화명', '평점', '일자'], header=None)
dfmv.head()

# %%
df = dfmv[['일자','영화명','순위', '평점']]
df.head()

# %%
df['일자'] = pd.to_datetime(df['일자'])
df.dtypes

# %%
df2019 = df[df['일자'].dt.year == 2019]
df2019.head()

# %%
df2019['일자'] = df2019['일자'].astype(str)
df2019.dtypes

# %%
df2019 = df2019.set_index('일자')
df2019.head()

# %%
df2019.loc['평균'] = df2019.mean(axis=0)
df2019

# %%
df2019.loc['평균', '영화명'] = ''
df2019.loc['평균', '순위'] = ''

df2019.tail()

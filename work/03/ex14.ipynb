# %% [markdown]
# <a href="https://colab.research.google.com/github/cybermin/pythonbasic/blob/master/work/03/ex14.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
with open('/content/drive/My Drive/PythonWork/PythonBasic/work/03/data.json', 'r',encoding='utf-8') as fp:
    data = fp.readlines()

# %%
data
# Out:
# ['{\n',
#  '    "request_id": "0",\n',
#  '    "return_type": "omAnalysis",\n',
#  '    "result": 0,\n',
#  '    "reason": "",\n',
#  '    "return_object": {\n',
#  '        "query": "한국의 가을은 매우 아름답습니다.",\n',
#  '        "type": "감성분석",\n',
#  '        "score": 0.9999995231628418,\n',
#  '        "label": "긍정"\n',
#  '    },\n',
#  '    "result_code": "success"\n',
#  '}']

# %%
with open('/content/drive/My Drive/PythonWork/PythonBasic/work/03/data.json', 'r',encoding='utf-8') as fp:
    data = fp.read()

print(data)
print(type(data))
# Out:
# {
#     "request_id": "0",
#     "return_type": "omAnalysis",
#     "result": 0,
#     "reason": "",
#     "return_object": {
#         "query": "한국의 가을은 매우 아름답습니다.",
#         "type": "감성분석",
#         "score": 0.9999995231628418,
#         "label": "긍정"
#     },
#     "result_code": "success"
# }
# <class 'str'>

# %%
import json
dt = json.loads(data)

print(dt)
print(type(dt))
# Out:
# {'request_id': '0', 'return_type': 'omAnalysis', 'result': 0, 'reason': '', 'return_object': {'query': '한국의 가을은 매우 아름답습니다.', 'type': '감성분석', 'score': 0.9999995231628418, 'label': '긍정'}, 'result_code': 'success'}
# <class 'dict'>

# %%
print(dt["result_code"])
# Out:
# success

# %%
rt = dt["return_object"]
x = rt['score'] * 100
rate = f'{x:.2f}%'

s = f"{rt['query']} : {rt['type']} - {rt['label']} ( {rt['score'] * 100 :0.2f}% ) "
print(rt['query'], ':', rt['type'], '-', rt['label'] , '(', rate, ')') 
print(s)
# Out:
# 한국의 가을은 매우 아름답습니다. : 감성분석 - 긍정 ( 100.00% )
# 한국의 가을은 매우 아름답습니다. : 감성분석 - 긍정 ( 100.00% )

# %%
jdata = {
    "request_id": "0",
    "return_type": "omAnalysis",
    "result": 0,
    "reason": "",
    "return_object": {
        "query": "한국의 가을은 매우 아름답습니다.",
        "type": "감성분석",
        "score": 0.9999995231628418,
        "label": "긍정"
    },
    "result_code": "success"
}
print(type(jdata))
# Out:
# <class 'dict'>

# %%
jsonStr = json.dumps(jdata, indent='\t', ensure_ascii=False)
print(jsonStr)
print(type(jsonStr))
# Out:
# {
# 	"request_id": "0",
# 	"return_type": "omAnalysis",
# 	"result": 0,
# 	"reason": "",
# 	"return_object": {
# 		"query": "한국의 가을은 매우 아름답습니다.",
# 		"type": "감성분석",
# 		"score": 0.9999995231628418,
# 		"label": "긍정"
# 	},
# 	"result_code": "success"
# }
# <class 'str'>

# %%
jsonStr2 = str(jdata)
print(jsonStr2)
print(type(jsonStr2))
# Out:
# {'request_id': '0', 'return_type': 'omAnalysis', 'result': 0, 'reason': '', 'return_object': {'query': '한국의 가을은 매우 아름답습니다.', 'type': '감성분석', 'score': 0.9999995231628418, 'label': '긍정'}, 'result_code': 'success'}
# <class 'str'>

# %%
lt = jsonStr.split(',')
print(lt)
for item in lt:
    print("item : " , item)
# Out:
# ['{"request_id": "0"', ' "return_type": "omAnalysis"', ' "result": 0', ' "reason": ""', ' "return_object": {"query": "\\ud55c\\uad6d\\uc758 \\uac00\\uc744\\uc740 \\ub9e4\\uc6b0 \\uc544\\ub984\\ub2f5\\uc2b5\\ub2c8\\ub2e4."', ' "type": "\\uac10\\uc131\\ubd84\\uc11d"', ' "score": 0.9999995231628418', ' "label": "\\uae0d\\uc815"}', ' "result_code": "success"}']
# item :  {"request_id": "0"
# item :   "return_type": "omAnalysis"
# item :   "result": 0
# item :   "reason": ""
# item :   "return_object": {"query": "\ud55c\uad6d\uc758 \uac00\uc744\uc740 \ub9e4\uc6b0 \uc544\ub984\ub2f5\uc2b5\ub2c8\ub2e4."
# item :   "type": "\uac10\uc131\ubd84\uc11d"
# item :   "score": 0.9999995231628418
# item :   "label": "\uae0d\uc815"}
# item :   "result_code": "success"}

# %%
from urllib.request import urlopen

#import urllib.request

# %%
url = 'http://www.naver.com'
data = urlopen(url).read()
print(data)
# Out:
# b'\n<!doctype html>                     <html lang="ko" data-dark="false"> <head> <meta charset="utf-8"> <title>NAVER</title> <meta http-equiv="X-UA-Compatible" content="IE=edge"> <meta name="viewport" content="width=1190"> <meta name="apple-mobile-web-app-title" content="NAVER"/> <meta name="robots" content="index,nofollow"/> <meta name="description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84 \xeb\xa9\x94\xec\x9d\xb8\xec\x97\x90\xec\x84\x9c \xeb\x8b\xa4\xec\x96\x91\xed\x95\x9c \xec\xa0\x95\xeb\xb3\xb4\xec\x99\x80 \xec\x9c\xa0\xec\x9a\xa9\xed\x95\x9c \xec\xbb\xa8\xed\x85\x90\xec\xb8\xa0\xeb\xa5\xbc \xeb\xa7\x8c\xeb\x82\x98 \xeb\xb3\xb4\xec\x84\xb8\xec\x9a\x94"/> <meta property="og:title" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x84"> <meta property="og:url" content="https://www.naver.com/"> <meta property="og:image" content="https://s.pstatic.net/static/www/mobile/edit/2016/0705/mobile_212852414260.png"> <meta property="og:description" content="\xeb\x84\xa4\xec\x9d\xb4\xeb\xb2\x8
# ...

# %%
#영화 공공데이터 : http://www.kobis.or.kr/kobisopenapi/homepg/apiservice/searchServiceInfo.do

url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.xml?key=430156241533f1d058c603178cc3ca0e&targetDt=20120101'
data = urlopen(url).read()
print(data)
# Out:
# b'<?xml version="1.0" encoding="utf-8" standalone="yes"?><boxOfficeResult><boxofficeType>\xec\x9d\xbc\xeb\xb3\x84 \xeb\xb0\x95\xec\x8a\xa4\xec\x98\xa4\xed\x94\xbc\xec\x8a\xa4</boxofficeType><showRange>20120101~20120101</showRange><dailyBoxOfficeList><dailyBoxOffice><rnum>1</rnum><rank>1</rank><rankInten>0</rankInten><rankOldAndNew>OLD</rankOldAndNew><movieCd>20112207</movieCd><movieNm>\xeb\xaf\xb8\xec\x85\x98\xec\x9e\x84\xed\x8c\x8c\xec\x84\x9c\xeb\xb8\x94:\xea\xb3\xa0\xec\x8a\xa4\xed\x8a\xb8\xed\x94\x84\xeb\xa1\x9c\xed\x86\xa0\xec\xbd\x9c</movieNm><openDt>2011-12-15</openDt><salesAmt>2776060500</salesAmt><salesShare>36.3</salesShare><salesInten>-415699000</salesInten><salesChange>-13</salesChange><salesAcc>40541108500</salesAcc><audiCnt>353274</audiCnt><audiInten>-60106</audiInten><audiChange>-14.5</audiChange><audiAcc>5328435</audiAcc><scrnCnt>697</scrnCnt><showCnt>3223</showCnt></dailyBoxOffice><dailyBoxOffice><rnum>2</rnum><rank>2</rank><rankInten>1</rankInten><rankOldAndNew>OLD<
# ...

# %%
#영화진흥 공공데이터 가져오기 : json형태 문자열로 가져오기 
def movieRank(cdate) :
    mykey = '430156241533f1d058c603178cc3ca0e'

    url = 'http://www.kobis.or.kr/kobisopenapi/webservice/rest/boxoffice/searchDailyBoxOfficeList.json'
    url = url + '?key=' + mykey 
    url = url + '&targetDt=' + cdate

    data = urlopen(url).read().decode('utf-8')

    return data

# %%
#영화 json 문자열을 딕션너리로 변환 
#해당하는 영화 명을 리스트로 반환
def movieList(data) :
    mlt = []

    #딕션너리 변환
    dt = json.loads(data)

    #1위에서 10까지 영화 항목을 dl에 저장 : 1위 부터 10까지 딕션너리의 리스트 
    dl = dt['boxOfficeResult']['dailyBoxOfficeList'] 
    for item in dl: 
        mlt.append(item['movieNm']) 

    return mlt

# %%
#리스트 항목보기
def show(mlt) :
    for item in mlt :
        print(item)

# %%
if __name__ == '__main__' :
    cdate = input('날짜입력(yyyymmdd)')
    data = movieRank(cdate) 
    mlist = movieList(data)

    show(mlist)
# Out:
# 날짜입력(yyyymmdd)20200701
# #살아있다
# 결백
# 소리꾼
# 다크 나이트
# 온워드: 단 하루의 기적
# 인베이젼 2020
# 위대한 쇼맨
# 부산행:익스텐디드
# 해피 디 데이
# 야구소녀
